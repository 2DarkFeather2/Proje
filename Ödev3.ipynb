# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
# 1)
df.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model_year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model_year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model_year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
# 2)
corr = df.corr()
mpg = corr['mpg'].sort_values(ascending=False)
mpg
# Out:
# mpg             1.000000
# model_year      0.579267
# origin          0.563450
# acceleration    0.420289
# cylinders      -0.775396
# displacement   -0.804203
# weight         -0.831741
# Name: mpg, dtype: float64

# %%
# 3)
df['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
# 4)
df['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
# 5)
df[(df['model_year'] >= 75) & (df['model_year'] <= 80)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 152  19.0          6         225.0         95    3264          16.0
# 153  18.0          6         250.0        105    3459          16.0
# 154  15.0          6         250.0         72    3432          21.0
# 155  15.0          6         250.0         72    3158          19.5
# 156  16.0          8         400.0        170    4668          11.5
# ..    ...        ...           ...        ...     ...           ...
# 333  32.7          6         168.0        132    2910          11.4
# 334  23.7          3          70.0        100    2420          12.5
# 335  35.0          4         122.0         88    2500          15.1
# 336  23.6          4         140.0          ?    2905          14.3
# 337  32.4          4         107.0         72    2290          17.0
#
#      model_year  origin                     name
# 152          75       1  plymouth valiant custom
# 153          75       1           chevrolet nova
# ...

# %%
# 6)
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df[(df['horsepower'] >= 155) & (df['horsepower'] < 180)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 1    15.0          8         350.0       165.0    3693          11.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 38   14.0          8         350.0       165.0    4209          12.0
# 39   14.0          8         400.0       175.0    4464          11.5
# 43   13.0          8         400.0       170.0    4746          12.0
# 44   13.0          8         400.0       175.0    5140          12.0
# 62   13.0          8         350.0       165.0    4274          12.0
# 63   14.0          8         400.0       175.0    4385          12.0
# 68   13.0          8         350.0       155.0    4502          13.5
# 69   12.0          8         350.0       160.0    4456          13.5
# 85   13.0          8         350.0       175.0    4100          13.0
# 92   13.0          8         351.0       158.0    4363          13.0
# ...

# %%
# 7)
df = df.sort_values(by='horsepower', ascending=False).reset_index(drop=True)
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    16.0          8         400.0       230.0    4278           9.5
# 1    14.0          8         455.0       225.0    4425          10.0
# 2    12.0          8         455.0       225.0    4951          11.0
# 3    14.0          8         455.0       225.0    3086          10.0
# 4    14.0          8         454.0       220.0    4354           9.0
# ..    ...        ...           ...         ...     ...           ...
# 393  21.0          6         200.0         NaN    2875          17.0
# 394  40.9          4          85.0         NaN    1835          17.3
# 395  23.6          4         140.0         NaN    2905          14.3
# 396  34.5          4         100.0         NaN    2320          15.8
# 397  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                      name
# 0            73       1        pontiac grand prix
# ...

# %%
# 8)
df.sort_values(by='acceleration')
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 11   14.0          8         340.0        160    3609           8.0
# 9    15.0          8         390.0        190    3850           8.5
# 7    14.0          8         440.0        215    4312           8.5
# 6    14.0          8         454.0        220    4354           9.0
# 116  16.0          8         400.0        230    4278           9.5
# ..    ...        ...           ...        ...     ...           ...
# 300  23.9          8         260.0         90    3420          22.2
# 59   23.0          4          97.0         54    2254          23.5
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 299  27.2          4         141.0         71    3190          24.8
#
#      model_year  origin                               name
# 11           70       1                 plymouth 'cuda 340
# ...

# %%
df = pd.read_csv('CIA_Country_Facts.csv')
df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
# 9)
len(df['Country'].unique())
# Out:
# 227

# %%
# 10)
df.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
# 11)
tamamı_nan = df.isnull().all(axis=1)
en_az_bir_nan = df.isnull().any(axis=1)

if tamamı_nan.any():
    df = df[~tamamı_nan]
    print("Tamamen nan değerlerden oluşan satır düşürüldü.")
elif en_az_bir_nan.all():
    print("Tüm satırlar nan değerlerden oluşuyor.")
else:
    print("Tamamen nan değerlerden oluşan satır yok.")
# Out:
# Tamamen nan değerlerden oluşan satır yok.

# %%
# 12)
df.groupby('Region')['Population'].sum()
# Out:
# Region
# ASIA (EX. NEAR EAST)                   3687982236
# BALTICS                                   7184974
# C.W. OF IND. STATES                     280081548
# EASTERN EUROPE                          119914717
# LATIN AMER. & CARIB                     561824599
# NEAR EAST                               195068377
# NORTHERN AFRICA                         161407133
# NORTHERN AMERICA                        331672307
# OCEANIA                                  33131662
# SUB-SAHARAN AFRICA                      749437000
# WESTERN EUROPE                          396339998
# Name: Population, dtype: int64

# %%
# 13)
df['Climate'].fillna(value=df['Climate'].mean(), inplace=True)
df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
# 14)
df.groupby(['Region', 'Country'])['Birthrate'].sum()
# Out:
# Region                               Country
# ASIA (EX. NEAR EAST)                 Afghanistan       46.60
#                                      Bangladesh        29.80
#                                      Bhutan            33.65
#                                      Brunei            18.79
#                                      Burma             17.91
#                                                        ...
# WESTERN EUROPE                       San Marino        10.02
#                                      Spain             10.06
#                                      Sweden            10.27
#                                      Switzerland        9.71
#                                      United Kingdom    10.71
# Name: Birthrate, Length: 227, dtype: float64

# %%
# 15)
df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
# 15/1)
# 1.GDP değerleri en yüksek olan ülkelerin çoğunun Avrupa veya Kuzey Amerika'da olduğu görülüyor.
# 2.Doğum oranları yüksek olan ülkelerin büyük çoğunluğu Afrika kıtasında yer almaktadır.
# 3.Toplam nüfusu en yüksek ülkeler arasında Çin ve Hindistan öne çıkmaktadır.
# 4.Bölgesel olarak incelendiğinde, Asya'da en fazla ülke bulunurken, Afrika en az sayıda ülkeye sahiptir.
# 5.Telefon sahipliği oranlarına bakıldığında gelişmiş ülkelerdeki insanların genellikle telefon sahibi olduğu görülmektedir. Ayrıca gelişmekte olan ülkelerde insanların büyük bir kısmı henüz telefon sahibi değil.
